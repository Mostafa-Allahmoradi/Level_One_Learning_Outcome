# %% [markdown]
# This notebook trains a public safety model that predicts crime by answering the question of "Will this stop lead to arrest?"
# Objective:

# %% [markdown]
# #### Choose the algorithm
#
# Machine Learning technique:
#
# Algorithm: Logistic Regression
#
# **Logistic Regression** is solely used for classification problems to predict probability using binary values like 0/1 or true/false or yes/no based on a set of independent variables.
#
# The output values lie between zero and one, the closer to one, the more confident the prediction is.

# %% [markdown]
# #### Imprort Libraries

# %% [markdown]
# #### Obtain and load the Data
#
# Source: Downloaded from []()
#
# This dataset is publicly available and it is comprised of stop-and-search data from the UK.
#
# The features from the stop-and-search dataset:
#     - Location
#     - Gender
#     - Age
#     - Ethnicity
#     - Time of day

# %% [markdown]
# #### Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Feature analysis from histogram plots

# %% [markdown]
# #### Data Preprocessing - Remove duplicates if any

# %% [markdown]
# #### Data Preprocessing - Handle categorical feature (One-hot encoding)

# %% [markdown]
# #### Data Preprocessing - Handle missing values
#
# We use K Nearest Neighbors (KNN)

# %% [markdown]
# #### Data Preprocessing - Remove outliers

# %% [markdown]
# #### Use a correlation heatmap to combine highly correlated features

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
# #### Train and Test split

# %% [markdown]
# #### Define a Model

# %% [markdown]
# #### Train the Model

# %% [markdown]
# #### Evaluate the Model

# %% [markdown]
# #### Testing the model

# %% [markdown]
# #### Talking points
