# %% [markdown]
# **Logistic Regression** is solely used for classification problems. It is used to predict the probability using binary values like zero/one or true/false or yes/no based on a set of independent variables. The output values lie between zero and one, the closer to one, the better.
